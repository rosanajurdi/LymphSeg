# %%
import pandas as pd

# %%
artf = pd.read_csv("/Users/rosana.eljurdi/Datasets/LymphSeg_dataset/val/metrics.csv")
l = artf.set_index('patient').dropna()

l[l['dice'] != 0].describe()
# Out:
#        Unnamed: 0       dice       hauss       MASD
# count   10.000000  10.000000   10.000000  10.000000
# mean     6.200000   0.711745   44.633505   7.003794
# std      3.938415   0.221676   50.599190   7.900830
# min      0.000000   0.185191    2.000000   0.388540
# 25%      3.250000   0.619410    4.860096   1.746292
# 50%      6.500000   0.771604   20.769556   4.600810
# 75%      8.750000   0.859322   74.137654  10.038960
# max     12.000000   0.938874  142.144293  26.170554

# %%
artf = pd.read_csv("/Users/rosana.eljurdi/Datasets/LymphSeg_dataset/train/metrics.csv")
l = artf.set_index('patient').dropna()

l[l['dice'] != 0].describe()
# Out:
#        Unnamed: 0       dice       hauss       MASD
# count   48.000000  48.000000   48.000000  48.000000
# mean    27.520833   0.866150   18.137582   2.069332
# std     16.041157   0.084679   33.393638   3.150679
# min      0.000000   0.600450    1.000000   0.119546
# 25%     14.500000   0.820733    2.000000   0.440176
# 50%     29.000000   0.893839    2.638958   0.702397
# 75%     41.250000   0.930029    7.873992   1.641551
# max     53.000000   0.955665  127.283149  13.382603

# %%
artf = pd.read_csv("/Users/rosana.eljurdi/Datasets/LymphSeg_dataset/test/metrics.csv")
l = artf.set_index('patient').dropna()

l[l['dice'] != 0].describe()
# Out:
#              Unnamed: 0      dice       hauss  \
# patient
# sub-1070222           0  0.866688    9.949874
# sub-1070741           1  0.767354    9.273618
# sub-1071130           2  0.055808   42.871902
# sub-1071219           3  0.808431    5.385165
# sub-1071241           4  0.094937  153.456834
# sub-1071252           5  0.772237    8.602325
# sub-1071364           6  0.823227    6.000000
# sub-1071513           7  0.879833    6.324555
# sub-1071646           8  0.215084   31.780497
# sub-1071792           9  0.869331   10.344080
# sub-1072004          10  0.000000  157.588071
# sub-1072120          11  0.633511   49.578221
# sub-1072550          12  0.738756   27.440845
# sub-1072782          13  0.701136   15.165751
# sub-1072858          14  0.769979   10.392305
# sub-1073463          15  0.730480    5.000000
# sub-1073847          16  0.803691   39.331921
# sub-1073888          17  0.737922   17.029386
# sub-1075196          18  0.343193   51.855569
# ...

# %%
artf = pd.read_csv("/Users/rosana.eljurdi/Datasets/LymphSeg_dataset/artf_test/metrics.csv")
l = artf.set_index('patient').dropna()

l[l['dice'] != 0].describe()
# Out:
#        Unnamed: 0       dice      hauss       MASD
# count   15.000000  15.000000  15.000000  15.000000
# mean     8.866667   0.695231  27.044033   4.323619
# std      6.104643   0.243530  17.962867   4.845572
# min      0.000000   0.220276   4.000000   0.537273
# 25%      4.500000   0.517225   9.427805   1.446423
# 50%      8.000000   0.780983  24.879711   3.093522
# 75%     13.000000   0.905172  41.766182   5.181537
# max     20.000000   0.923494  59.715995  20.096425
